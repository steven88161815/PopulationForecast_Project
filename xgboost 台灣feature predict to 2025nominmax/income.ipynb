# Kaohsiung City   319905  304104  321015  328911

# %%
col = []
for i in df1.columns:
    col.append(str(i))
col
# Out:
# ['98', '99', '100', '101', '102', '103', '104', '105', '106', '107']

# %%
df1.columns = col
df1
# Out:
#                             98      99     100     101     102     103  \
# Unnamed: 0
# New Taipei City  265140.804598  273351  279239  278023  284783  291591
# Taipei City      387052.795031  402056  381561  398217  408688  412973
# Taoyuan City     268840.571429  272470  273295  287727  288668  314701
# Taichung City    263142.638037  279324  265316  271157  282352  303365
# Tainan City      263413.109756  252184  245524  242163  261153  266012
# Kaohsiung City   291891.194969  311566  270996  283843  295244  300872
#
#                     104     105     106     107
# Unnamed: 0
# New Taipei City  305575  326152  337605  350606
# Taipei City      426633  440278  436538  436489
# Taoyuan City     311248  325471  327133  346623
# Taichung City    311948  322806  337637  343713
# Tainan City      269302  286254  293031  293762
# Kaohsiung City   319905  304104  321015  328911

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, New Taipei City to Kaohsiung City
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   98      6 non-null      float64
#  1   99      6 non-null      int64
#  2   100     6 non-null      int64
#  3   101     6 non-null      int64
#  4   102     6 non-null      int64
#  5   103     6 non-null      int64
#  6   104     6 non-null      int64
#  7   105     6 non-null      int64
#  8   106     6 non-null      int64
#  9   107     6 non-null      int64
# dtypes: float64(1), int64(9)
# memory usage: 528.0+ bytes

# %% [markdown]
# ### input為n維

# %%
d = int(input('輸入的維度：'))
x_train = []
y_train = []
x_test = []
y_test = []

for a in range(2):
    x_test.append([])
    y_test.append([])

for b in range(8-d):
    x_train.append([])
    y_train.append([])
    
for i in range(2):
    x_test[i] = (df1.iloc[:, -2-d+i:-2+i].values)
    y_test[i] = (df1.iloc[:, -2+i].values)

for j in range(8-d):
    x_train[j] = (df1.iloc[:, j:d+j].values)
    y_train[j] = (df1.iloc[:, d+j].values)
# Out:
# 輸入的維度：2

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
x_train
# Out:
# array([[[265140.8045977 , 273351.        ],
#         [387052.79503106, 402056.        ],
#         [268840.57142857, 272470.        ],
#         [263142.63803681, 279324.        ],
#         [263413.1097561 , 252184.        ],
#         [291891.19496855, 311566.        ]],
#
#        [[273351.        , 279239.        ],
#         [402056.        , 381561.        ],
#         [272470.        , 273295.        ],
#         [279324.        , 265316.        ],
#         [252184.        , 245524.        ],
#         [311566.        , 270996.        ]],
#
#        [[279239.        , 278023.        ],
#         [381561.        , 398217.        ],
#         [273295.        , 287727.        ],
#         [265316.        , 271157.        ],
#         [245524.        , 242163.        ],
#         [270996.        , 283843.        ]],
#
#        [[278023.        , 284783.        ],
#         [398217.        , 408688.        ],
#         [287727.        , 288668.        ],
# ...

# %%
x_train.shape
# Out:
# (6, 6, 2)

# %%
y_train
# Out:
# array([[279239, 381561, 273295, 265316, 245524, 270996],
#        [278023, 398217, 287727, 271157, 242163, 283843],
#        [284783, 408688, 288668, 282352, 261153, 295244],
#        [291591, 412973, 314701, 303365, 266012, 300872],
#        [305575, 426633, 311248, 311948, 269302, 319905],
#        [326152, 440278, 325471, 322806, 286254, 304104]], dtype=int64)

# %%
y_train.shape
# Out:
# (6, 6)

# %%
x_test
# Out:
# array([[[305575, 326152],
#         [426633, 440278],
#         [311248, 325471],
#         [311948, 322806],
#         [269302, 286254],
#         [319905, 304104]],
#
#        [[326152, 337605],
#         [440278, 436538],
#         [325471, 327133],
#         [322806, 337637],
#         [286254, 293031],
#         [304104, 321015]]], dtype=int64)

# %%
y_test
# Out:
# array([[337605, 436538, 327133, 337637, 293031, 321015],
#        [350606, 436489, 346623, 343713, 293762, 328911]], dtype=int64)

# %%
x_train = x_train.reshape(-1, d)
y_train = y_train.ravel()
x_test = x_test.reshape(-1, d)
y_test = y_test.ravel()

# %%
x_train
# Out:
# array([[265140.8045977 , 273351.        ],
#        [387052.79503106, 402056.        ],
#        [268840.57142857, 272470.        ],
#        [263142.63803681, 279324.        ],
#        [263413.1097561 , 252184.        ],
#        [291891.19496855, 311566.        ],
#        [273351.        , 279239.        ],
#        [402056.        , 381561.        ],
#        [272470.        , 273295.        ],
#        [279324.        , 265316.        ],
#        [252184.        , 245524.        ],
#        [311566.        , 270996.        ],
#        [279239.        , 278023.        ],
#        [381561.        , 398217.        ],
#        [273295.        , 287727.        ],
#        [265316.        , 271157.        ],
#        [245524.        , 242163.        ],
#        [270996.        , 283843.        ],
#        [278023.        , 284783.        ],
#        [398217.        , 408688.        ],
#        [287727.        , 288668.        ],
#        [271157.        , 282352.        ],
# ...

# %%
y_train
# Out:
# array([279239, 381561, 273295, 265316, 245524, 270996, 278023, 398217,
#        287727, 271157, 242163, 283843, 284783, 408688, 288668, 282352,
#        261153, 295244, 291591, 412973, 314701, 303365, 266012, 300872,
#        305575, 426633, 311248, 311948, 269302, 319905, 326152, 440278,
#        325471, 322806, 286254, 304104], dtype=int64)

# %%
from xgboost import XGBRegressor
xgbr = XGBRegressor(n_estimators=100 , max_depth=3 , learning_rate=0.1, subsample=1, colsample_bynode=0.8, reg_lambda=1e-05)
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=0.8, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=12, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1e-05, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgbr.predict(x_test)
# Out:
# array([319269.88, 439715.38, 314659.4 , 314659.4 , 290551.  , 327438.78,
#        326955.9 , 439715.38, 326955.9 , 326955.9 , 305734.5 , 319269.88],
#       dtype=float32)

# %%
y_test
# Out:
# array([337605, 436538, 327133, 337637, 293031, 321015, 350606, 436489,
#        346623, 343713, 293762, 328911], dtype=int64)

# %%
for i in range(6):
    MAPE = abs((xgbr.predict(x_test)[i]- y_test[i])/y_test[i])+abs((xgbr.predict(x_test)[i+6]- y_test[i+6])/y_test[i+6])
    MAPE /= 2
    print('MAPE為', MAPE)
# Out:
# MAPE為 0.060882151560299344
# MAPE為 0.0073351142294274425
# MAPE為 0.04743459312039962
# MAPE為 0.05840364551259203
# MAPE為 0.02460952514143101
# MAPE為 0.024661552636186797

# %%
number = 0 
for i in range(6):
    MAPE = abs((xgbr.predict(x_test)[i]- y_test[i])/y_test[i])+abs((xgbr.predict(x_test)[i+6]- y_test[i+6])/y_test[i+6])
    MAPE /= 2
    number += MAPE
number /= 6
print('平均MAPE為', number)
# Out:
# 平均MAPE為 0.037221097033389376

# %%
number = 0
for i in range(len(xgbr.predict(x_test) - y_test)):
    number += ((xgbr.predict(x_test) - y_test)[i])**2
    
number /= len(xgbr.predict(x_test) - y_test)
print('平均MSE為', number)
# Out:
# 平均MSE為 212572623.90348306

# %% [markdown]
# ```
# 輸入為1D的平均MAPE為0.061073712083930524
#          平均MSE為 633095527.979899
# 輸入為2D的平均MAPE為0.037221097033389376
#          平均MSE為 212572623.90348306
# 輸入為3D的平均MAPE為0.054778624357550765
#          平均MSE為 490480931.38517255
# 輸入為4D的平均MAPE為0.054707829690290734
#          平均MSE為 521006446.75561523
# 輸入為5D的平均MAPE為0.05614738356079274
#          平均MSE為 505980214.0609538
# ```

# %% [markdown]
# ## 選擇2D！！！

# %%
df1
# Out:
#                             98      99     100     101     102     103  \
# Unnamed: 0
# New Taipei City  265140.804598  273351  279239  278023  284783  291591
# Taipei City      387052.795031  402056  381561  398217  408688  412973
# Taoyuan City     268840.571429  272470  273295  287727  288668  314701
# Taichung City    263142.638037  279324  265316  271157  282352  303365
# Tainan City      263413.109756  252184  245524  242163  261153  266012
# Kaohsiung City   291891.194969  311566  270996  283843  295244  300872
#
#                     104     105     106     107
# Unnamed: 0
# New Taipei City  305575  326152  337605  350606
# Taipei City      426633  440278  436538  436489
# Taoyuan City     311248  325471  327133  346623
# Taichung City    311948  322806  337637  343713
# Tainan City      269302  286254  293031  293762
# Kaohsiung City   319905  304104  321015  328911

# %%
df2 = df1.copy()
df2
# Out:
#                             98      99     100     101     102     103  \
# Unnamed: 0
# New Taipei City  265140.804598  273351  279239  278023  284783  291591
# Taipei City      387052.795031  402056  381561  398217  408688  412973
# Taoyuan City     268840.571429  272470  273295  287727  288668  314701
# Taichung City    263142.638037  279324  265316  271157  282352  303365
# Tainan City      263413.109756  252184  245524  242163  261153  266012
# Kaohsiung City   291891.194969  311566  270996  283843  295244  300872
#
#                     104     105     106     107
# Unnamed: 0
# New Taipei City  305575  326152  337605  350606
# Taipei City      426633  440278  436538  436489
# Taoyuan City     311248  325471  327133  346623
# Taichung City    311948  322806  337637  343713
# Tainan City      269302  286254  293031  293762
# Kaohsiung City   319905  304104  321015  328911

# %%
df2.iloc[:, -d:].values
# Out:
# array([[337605, 350606],
#        [436538, 436489],
#        [327133, 346623],
#        [337637, 343713],
#        [293031, 293762],
#        [321015, 328911]], dtype=int64)

# %%
xgbr.predict(df2.iloc[:, -d:].values)
# Out:
# array([327910.72, 439715.38, 327910.72, 326955.9 , 298768.56, 326955.9 ],
#       dtype=float32)

# %%
df2['108'] = xgbr.predict(df2.iloc[:, -d:].values)
