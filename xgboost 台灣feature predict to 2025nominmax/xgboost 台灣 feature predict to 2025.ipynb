# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.read_excel('birth_df.xlsx')
df1.index = list(range(1, 43, 6))
df1
# Out:
#             million      98      99     100     101     102     103     104  \
# 1   New Taipei City   32255   32093   27617   34323   22854   35915   38604
# 7       Taipei City   20691   19403   18530   25132   22258   26710   29024
# 13     Taoyuan City   19180   18515   15838   18041   16856   16757   17360
# 19    Taichung City   23647   22601   19537   24027   20499   24555   26194
# 25      Tainan City   14773   14196   11612   14208   17752   14788   15426
# 31   Kaohsiung City   22182   11116   18684   21411   24963   21626   22520
# 37           Taiwan  191310  166886  196627  229481  199113  210383  213598
#
#        105     106     107  108
# 1    36313   34331   31611  NaN
# 7    28987   27992   25042  NaN
# 13   22384   23786   23356  NaN
# 19   26313   25655   24338  NaN
# 25   22469   14698   13773  NaN
# 31   12044   21757   20260  NaN
# 37  208440  193844  181601  NaN

# %%
df2 = pd.read_excel('city_annual_expend_df.xlsx')
df2.index = list(range(2, 43, 6))
df2
# Out:
#             million             98             99            100  \
# 2   New Taipei City   96578.611019   98880.514918  101597.893147
# 8       Taipei City  148192.887258  155531.416179  162280.646270
# 14     Taoyuan City   45593.320794   48076.080794   48577.653444
# 20    Taichung City   75788.780000   74185.000000   77484.420000
# 26      Tainan City   58714.480000   59532.477000   64737.220000
# 32   Kaohsiung City  102063.120000  117931.345000  115951.800000
# 38           Taiwan  807522.000000  867824.000000  882066.000000
#
#               101            102            103            104           105  \
# 2   145899.009050  149866.518605  146754.099649  154473.463926  1.516608e+05
# 8   173139.571548  176075.234609  169580.238024  167504.327527  1.541876e+05
# 14   57174.898426   58093.627307   57736.471325   62760.000000  8.497782e+04
# 20   96887.312546   99883.362462  109538.016083  104869.032822  1.131774e+05
# ...

# %%
df3 = pd.read_excel('death_df.xlsx')
df3.index = list(range(3, 43, 6))
df3
# Out:
#             million      98      99     100     101     102     103     104  \
# 3   New Taipei City   17882   17959   18404   19774   20280   20746   21935
# 9       Taipei City   15606   15260   15398   15988   16579   16379   17177
# 15     Taoyuan City    9677    9790   10183   10878   10977   10972   11854
# 21    Taichung City   13826   13805   14340   14915   15017   15138   15968
# 27      Tainan City   13040   12990   13206   13941   13871   14021   14390
# 33   Kaohsiung City   17517   18189   18001   18845   18945   19277   20282
# 39           Taiwan  143582  145772  152915  154251  155908  163929  163858
#
#        105     106     107  108
# 3    22175   23256   23525  NaN
# 9    17106   17982   17467  NaN
# 15   11600   12637   12620  NaN
# 21   16070   16921   16904  NaN
# 27   20508   15234   14996  NaN
# 33   12779   21365   21368  NaN
# 39  172405  171242  172784  NaN

# %%
df4 = pd.read_excel('immigration_df.xlsx')
df4.index = list(range(4, 43, 6))
df4
# Out:
#             million     98     99    100    101    102    103   104    105  \
# 4   New Taipei City  21342  25789  14501   4535   2287    455 -4780 -10312
# 10      Taipei City -11431 -19638   8212  23052   9339   2959  3952  -9386
# 16     Taoyuan City  14215  11371  17623   4082   7967   8077  8799  36668
# 22    Taichung City   7457   2893   7461   6863   7192   7351  7948  14367
# 28      Tainan City   1211   1195    -18   2899    804    796    40  -2035
# 34   Kaohsiung City   -479  -1055   1913  -1579  -1829  -1131 -3123    102
# 40           Taiwan  35013  21237  19077  15680  14490  13782  6798  11707
#
#       106    107     108
# 4   -2511   -605  4030.0
# 10 -19116 -20022     NaN
# 16  30834  29518     NaN
# 22  14060  12397     NaN
# 28   1028   1712     NaN
# 34     61  -1351     NaN
# 40   8809   6770     NaN

# %%
df5 = pd.read_excel('per_capital_income_df.xlsx')
df5.index = list(range(5, 43, 6))
df5
# Out:
#          Unnamed: 0             98      99     100     101     102     103  \
# 5   New Taipei City  265140.804598  273351  279239  278023  284783  291591
# 11      Taipei City  387052.795031  402056  381561  398217  408688  412973
# 17     Taoyuan City  268840.571429  272470  273295  287727  288668  314701
# 23    Taichung City  263142.638037  279324  265316  271157  282352  303365
# 29      Tainan City  263413.109756  252184  245524  242163  261153  266012
# 35   Kaohsiung City  291891.194969  311566  270996  283843  295244  300872
# 41           Taiwan  473259.000000  524234  527186  537021  565198  607264
#
#        104     105     106     107     108
# 5   305575  326152  337605  350606  371156
# 11  426633  440278  436538  436489  458839
# 17  311248  325471  327133  346623  357432
# 23  311948  322806  337637  343713  352633
# 29  269302  286254  293031  293762  305444
# 35  319905  304104  321015  328911  331657
# 41  633367  650854  667945  678233  687140

# %%
df6 = pd.read_excel('population_df.xlsx')
df6.index = list(range(6, 43, 6))
df6
# Out:
#            location        98        99       100       101       102  \
# 6   New Taipei City   3873653   3897367   3916451   3939305   3954929
# 12      Taipei City   2607428   2618772   2650968   2673226   2686516
# 18     Taoyuan City   1978782   2002060   2013305   2030161   2044023
# 24    Taichung City   2635761   2648419   2664394   2684893   2701661
# 30      Tainan City   1875406   1873794   1876960   1881645   1883208
# 36   Kaohsiung City   2770887   2773483   2774470   2778659   2779877
# 42           Taiwan  23119772  23162123  23224912  23315822  23373517
#
#          103       104       105       106       107       108
# 6    3966818   3970644   3979208   3986689   3995717   4018696
# 12   2702315   2704810   2695704   2683257   2668572   2645041
# 18   2058328   2105780   2147763   2188017   2220872   2249037
# 24   2719835   2744445   2767239   2787070   2803894   2815261
# 30   1884284   1885541   1886033   1886522   1883831   1880906
# ...

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
print(df4.columns)
print(df5.columns)
print(df6.columns)
# Out:
# Index(['million', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')
# Index(['million', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')
# Index(['million', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')
# Index(['million', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')
# Index(['Unnamed: 0', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')
# Index(['location', 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108], dtype='object')

# %%
box = ['']
box.extend(list(range(2009, 2020)))
box
# Out:
# ['', 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
len(box)
# Out:
# 12

# %%
df1.columns = box
df2.columns = box
df3.columns = box
df4.columns = box
df5.columns = box
df6.columns = box

# %%
df = df1
df
# Out:
#                        2009    2010    2011    2012    2013    2014    2015  \
# 1   New Taipei City   32255   32093   27617   34323   22854   35915   38604
# 7       Taipei City   20691   19403   18530   25132   22258   26710   29024
# 13     Taoyuan City   19180   18515   15838   18041   16856   16757   17360
# 19    Taichung City   23647   22601   19537   24027   20499   24555   26194
# 25      Tainan City   14773   14196   11612   14208   17752   14788   15426
# 31   Kaohsiung City   22182   11116   18684   21411   24963   21626   22520
# 37           Taiwan  191310  166886  196627  229481  199113  210383  213598
#
#       2016    2017    2018  2019
# 1    36313   34331   31611   NaN
# 7    28987   27992   25042   NaN
# 13   22384   23786   23356   NaN
# 19   26313   25655   24338   NaN
# 25   22469   14698   13773   NaN
# 31   12044   21757   20260   NaN
# 37  208440  193844  181601   NaN

# %%
df = pd.concat([df, df2, df3, df4, df5, df6])

# %%
df
# Out:
#                              2009          2010          2011          2012  \
# 1   New Taipei City  3.225500e+04  3.209300e+04  2.761700e+04  3.432300e+04
# 7       Taipei City  2.069100e+04  1.940300e+04  1.853000e+04  2.513200e+04
# 13     Taoyuan City  1.918000e+04  1.851500e+04  1.583800e+04  1.804100e+04
# 19    Taichung City  2.364700e+04  2.260100e+04  1.953700e+04  2.402700e+04
# 25      Tainan City  1.477300e+04  1.419600e+04  1.161200e+04  1.420800e+04
# 31   Kaohsiung City  2.218200e+04  1.111600e+04  1.868400e+04  2.141100e+04
# 37           Taiwan  1.913100e+05  1.668860e+05  1.966270e+05  2.294810e+05
# 2   New Taipei City  9.657861e+04  9.888051e+04  1.015979e+05  1.458990e+05
# 8       Taipei City  1.481929e+05  1.555314e+05  1.622806e+05  1.731396e+05
# 14     Taoyuan City  4.559332e+04  4.807608e+04  4.857765e+04  5.717490e+04
# 20    Taichung City  7.578878e+04  7.418500e+04  7.748442e+04  9.688731e+04
# ...

# %%
len(df)
# Out:
# 42

# %%
df = df.sort_index()
df
# Out:
#                              2009          2010          2011          2012  \
# 1   New Taipei City  3.225500e+04  3.209300e+04  2.761700e+04  3.432300e+04
# 2   New Taipei City  9.657861e+04  9.888051e+04  1.015979e+05  1.458990e+05
# 3   New Taipei City  1.788200e+04  1.795900e+04  1.840400e+04  1.977400e+04
# 4   New Taipei City  2.134200e+04  2.578900e+04  1.450100e+04  4.535000e+03
# 5   New Taipei City  2.651408e+05  2.733510e+05  2.792390e+05  2.780230e+05
# 6   New Taipei City  3.873653e+06  3.897367e+06  3.916451e+06  3.939305e+06
# 7       Taipei City  2.069100e+04  1.940300e+04  1.853000e+04  2.513200e+04
# 8       Taipei City  1.481929e+05  1.555314e+05  1.622806e+05  1.731396e+05
# 9       Taipei City  1.560600e+04  1.526000e+04  1.539800e+04  1.598800e+04
# 10      Taipei City -1.143100e+04 -1.963800e+04  8.212000e+03  2.305200e+04
# 11      Taipei City  3.870528e+05  4.020560e+05  3.815610e+05  3.982170e+05
# ...

# %%
term = ['birth', 'city_annual_expend', 'death', 'immigration', 'per_capital_income', 'population']
term = 7*term
len(term)
# Out:
# 42

# %%
df.insert(1, 'term', term)
df
# Out:
#                                    term          2009          2010  \
# 1   New Taipei City               birth  3.225500e+04  3.209300e+04
# 2   New Taipei City  city_annual_expend  9.657861e+04  9.888051e+04
# 3   New Taipei City               death  1.788200e+04  1.795900e+04
# 4   New Taipei City         immigration  2.134200e+04  2.578900e+04
# 5   New Taipei City  per_capital_income  2.651408e+05  2.733510e+05
# 6   New Taipei City          population  3.873653e+06  3.897367e+06
# 7       Taipei City               birth  2.069100e+04  1.940300e+04
# 8       Taipei City  city_annual_expend  1.481929e+05  1.555314e+05
# 9       Taipei City               death  1.560600e+04  1.526000e+04
# 10      Taipei City         immigration -1.143100e+04 -1.963800e+04
# 11      Taipei City  per_capital_income  3.870528e+05  4.020560e+05
# 12      Taipei City          population  2.607428e+06  2.618772e+06
# 13     Taoyuan City               birth  1.918000e+04  1.851500e+04
# ...

# %%
df.index = df['']
df
# Out:
#                                                 term          2009  \
#
# New Taipei City  New Taipei City               birth  3.225500e+04
# New Taipei City  New Taipei City  city_annual_expend  9.657861e+04
# New Taipei City  New Taipei City               death  1.788200e+04
# New Taipei City  New Taipei City         immigration  2.134200e+04
# New Taipei City  New Taipei City  per_capital_income  2.651408e+05
# New Taipei City  New Taipei City          population  3.873653e+06
# Taipei City          Taipei City               birth  2.069100e+04
# Taipei City          Taipei City  city_annual_expend  1.481929e+05
# Taipei City          Taipei City               death  1.560600e+04
# Taipei City          Taipei City         immigration -1.143100e+04
# Taipei City          Taipei City  per_capital_income  3.870528e+05
# Taipei City          Taipei City          population  2.607428e+06
# Taoyuan City        Taoyuan City               birth  1.918000e+04
# ...

# %%
df.columns
# Out:
# Index(['', 'term', 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019],
#       dtype='object')

# %%
df = df[['term', 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]] 
df
# Out:
#                                term          2009          2010          2011  \
#
# New Taipei City               birth  3.225500e+04  3.209300e+04  2.761700e+04
# New Taipei City  city_annual_expend  9.657861e+04  9.888051e+04  1.015979e+05
# New Taipei City               death  1.788200e+04  1.795900e+04  1.840400e+04
# New Taipei City         immigration  2.134200e+04  2.578900e+04  1.450100e+04
# New Taipei City  per_capital_income  2.651408e+05  2.733510e+05  2.792390e+05
# New Taipei City          population  3.873653e+06  3.897367e+06  3.916451e+06
# Taipei City                   birth  2.069100e+04  1.940300e+04  1.853000e+04
# Taipei City      city_annual_expend  1.481929e+05  1.555314e+05  1.622806e+05
# Taipei City                   death  1.560600e+04  1.526000e+04  1.539800e+04
# Taipei City             immigration -1.143100e+04 -1.963800e+04  8.212000e+03
# Taipei City      per_capital_income  3.870528e+05  4.020560e+05  3.815610e+05
# ...

# %%
df.shape
# Out:
# (42, 12)

# %%
df = df.T
df
# Out:
#      New Taipei City     New Taipei City New Taipei City New Taipei City  \
# term           birth  city_annual_expend           death     immigration
# 2009           32255             96578.6           17882           21342
# 2010           32093             98880.5           17959           25789
# 2011           27617              101598           18404           14501
# 2012           34323              145899           19774            4535
# 2013           22854              149867           20280            2287
# 2014           35915              146754           20746             455
# 2015           38604              154473           21935           -4780
# 2016           36313              151661           22175          -10312
# 2017           34331              148828           23256           -2511
# 2018           31611              148828           23525            -605
# 2019             NaN              166966             NaN            4030
#
# ...

# %%
df.loc['term'][0]
# Out:
# 'birth'

# %%
df.columns[0]
# Out:
# 'New Taipei City'

# %%
term = []
for i in range(42):
    term.append(df.columns[i]+' '+df.loc['term'][i])
term
# Out:
# ['New Taipei City birth',
#  'New Taipei City city_annual_expend',
#  'New Taipei City death',
#  'New Taipei City immigration',
#  'New Taipei City per_capital_income',
#  'New Taipei City population',
#  'Taipei City birth',
#  'Taipei City city_annual_expend',
#  'Taipei City death',
#  'Taipei City immigration',
#  'Taipei City per_capital_income',
#  'Taipei City population',
#  'Taoyuan City birth',
#  'Taoyuan City city_annual_expend',
#  'Taoyuan City death',
#  'Taoyuan City immigration',
#  'Taoyuan City per_capital_income',
#  'Taoyuan City population',
#  'Taichung City birth',
#  'Taichung City city_annual_expend',
#  'Taichung City death',
#  'Taichung City immigration',
#  'Taichung City per_capital_income',
#  'Taichung City population',
#  'Tainan City birth',
#  'Tainan City city_annual_expend',
#  'Tainan City death',
#  'Tainan City immigration',
#  'Tainan City per_capital_income',
#  'Tainan City population',
#  'Kaohsiung City birth',
# ...

# %%
len(term)
# Out:
# 42

# %%
df
# Out:
#      New Taipei City     New Taipei City New Taipei City New Taipei City  \
# term           birth  city_annual_expend           death     immigration
# 2009           32255             96578.6           17882           21342
# 2010           32093             98880.5           17959           25789
# 2011           27617              101598           18404           14501
# 2012           34323              145899           19774            4535
# 2013           22854              149867           20280            2287
# 2014           35915              146754           20746             455
# 2015           38604              154473           21935           -4780
# 2016           36313              151661           22175          -10312
# 2017           34331              148828           23256           -2511
# 2018           31611              148828           23525            -605
# 2019             NaN              166966             NaN            4030
#
# ...

# %%
df.columns = term
df = df.drop(['term'])
df
# Out:
#      New Taipei City birth New Taipei City city_annual_expend  \
# 2009                 32255                            96578.6
# 2010                 32093                            98880.5
# 2011                 27617                             101598
# 2012                 34323                             145899
# 2013                 22854                             149867
# 2014                 35915                             146754
# 2015                 38604                             154473
# 2016                 36313                             151661
# 2017                 34331                             148828
# 2018                 31611                             148828
# 2019                   NaN                             166966
#
#      New Taipei City death New Taipei City immigration  \
# 2009                 17882                       21342
# 2010                 17959                       25789
# ...

# %%
New_Taipei = df.iloc[:,0:6]
Taipei = df.iloc[:,6:12]
Taoyuan = df.iloc[:,12:18]
Taichung = df.iloc[:,18:24]
Tainan = df.iloc[:,24:30]
Kaohsiung = df.iloc[:,30:36]
Taiwan = df.iloc[:,36:42]

# %%
# 導入機器學習相關套件
from sklearn.model_selection import train_test_split
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.feature_selection import SelectFromModel

# %%
# 看一下分割完的其中一個有無出錯
New_Taipei
# Out:
#      New Taipei City birth New Taipei City city_annual_expend  \
# 2009                 32255                            96578.6
# 2010                 32093                            98880.5
# 2011                 27617                             101598
# 2012                 34323                             145899
# 2013                 22854                             149867
# 2014                 35915                             146754
# 2015                 38604                             154473
# 2016                 36313                             151661
# 2017                 34331                             148828
# 2018                 31611                             148828
# 2019                   NaN                             166966
#
#      New Taipei City death New Taipei City immigration  \
# 2009                 17882                       21342
# 2010                 17959                       25789
# ...

# %%
Taiwan
# Out:
#      Taiwan birth Taiwan city_annual_expend Taiwan death Taiwan immigration  \
# 2009       191310                    807522       143582              35013
# 2010       166886                    867824       145772              21237
# 2011       196627                    882066       152915              19077
# 2012       229481                    986397       154251              15680
# 2013       199113                    998285       155908              14490
# 2014       210383                    987590       163929              13782
# 2015       213598                    999547       163858               6798
# 2016       208440               1.00224e+06       172405              11707
# 2017       193844                1.0149e+06       171242               8809
# 2018       181601               1.03651e+06       172784               6770
# 2019          NaN                       NaN          NaN                NaN
#
#      Taiwan per_capital_income Taiwan population
# ...

# %%
x1 = New_Taipei.iloc[:-1, 0:5]
y1 = New_Taipei.iloc[:-1, 5]
x2 = Taipei.iloc[:-1, 0:5]
y2 = Taipei.iloc[:-1, 5]
x3 = Taoyuan.iloc[:-1, 0:5]
y3 = Taoyuan.iloc[:-1, 5]
x4 = Taichung.iloc[:-1, 0:5]
y4 = Taichung.iloc[:-1, 5]
x5 = Tainan.iloc[:-1, 0:5]
y5 = Tainan.iloc[:-1, 5]
x6 = Kaohsiung.iloc[:-1, 0:5]
y6 = Kaohsiung.iloc[:-1, 5]
x7 = Taiwan.iloc[:-1, 0:5]
y7 = Taiwan.iloc[:-1, 5]

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=87)
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2, random_state=87)
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.2, random_state=87)
x4_train, x4_test, y4_train, y4_test = train_test_split(x4, y4, test_size=0.2, random_state=87)
x5_train, x5_test, y5_train, y5_test = train_test_split(x5, y5, test_size=0.2, random_state=87)
x6_train, x6_test, y6_train, y6_test = train_test_split(x6, y6, test_size=0.2, random_state=87)
x7_train, x7_test, y7_train, y7_test = train_test_split(x7, y7, test_size=0.2, random_state=87)

# %%
fea1 = x1_train
fea2 = x2_train
fea3 = x3_train
fea4 = x4_train
fea5 = x5_train
fea6 = x6_train
fea7 = x7_train

# %%
x1_train
# Out:
#      New Taipei City birth New Taipei City city_annual_expend  \
# 2016                 36313                             151661
# 2014                 35915                             146754
# 2010                 32093                            98880.5
# 2009                 32255                            96578.6
# 2012                 34323                             145899
# 2017                 34331                             148828
# 2018                 31611                             148828
# 2015                 38604                             154473
#
#      New Taipei City death New Taipei City immigration  \
# 2016                 22175                      -10312
# 2014                 20746                         455
# 2010                 17959                       25789
# 2009                 17882                       21342
# 2012                 19774                        4535
# 2017                 23256                       -2511
# ...

# %%
x1_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 2016 to 2015
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   New Taipei City birth               8 non-null      object
#  1   New Taipei City city_annual_expend  8 non-null      object
#  2   New Taipei City death               8 non-null      object
#  3   New Taipei City immigration         8 non-null      object
#  4   New Taipei City per_capital_income  8 non-null      object
# dtypes: object(5)
# memory usage: 384.0+ bytes

# %%
x1_train = x1_train.values
x2_train = x2_train.values
x3_train = x3_train.values
x4_train = x4_train.values
x5_train = x5_train.values
x6_train = x6_train.values
x7_train = x7_train.values

# %%
x1_test = x1_test.values
x2_test = x2_test.values
x3_test = x3_test.values
x4_test = x4_test.values
x5_test = x5_test.values
x6_test = x6_test.values
x7_test = x7_test.values

# %%
y1_train = y1_train.values
y2_train = y2_train.values
y3_train = y3_train.values
y4_train = y4_train.values
y5_train = y5_train.values
y6_train = y6_train.values
y7_train = y7_train.values

# %%
y1_test = y1_test.values
y2_test = y2_test.values
y3_test = y3_test.values
y4_test = y4_test.values
y5_test = y5_test.values
y6_test = y6_test.values
y7_test = y7_test.values

# %% [markdown]
# ### 新北市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x1_train, y1_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.2, max_delta_step=0, max_depth=1,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=40, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgbr.predict(x1_test)
# Out:
# array([3897955. , 3969329.5], dtype=float32)

# %%
y1_test
# Out:
# array([3916451.0, 3954929.0], dtype=object)

# %%
xgbr.predict(x1_test)-y1_test
# Out:
# array([-18496.0, 14400.5], dtype=object)

# %%
mse = 0
for i in range(2):
    mse += ((xgbr.predict(x1_test)-y1_test)[i])**2    
mse = mse/2
print(mse)
# Out:
# 274738208.125

# %%
# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))
# Out:
# Feature: 1, Score: 0.03554
# Feature: 2, Score: 0.87333
# Feature: 3, Score: 0.09113
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000

# %%
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea1.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 台北市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x2_train, y2_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea2.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.68249
# Feature: 2, Score: 0.16892
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.08675
# Feature: 5, Score: 0.06184
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 桃園市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x3_train, y3_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea3.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.50818
# Feature: 2, Score: 0.37392
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.11790
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 台中市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x4_train, y4_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea4.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.52989
# Feature: 2, Score: 0.12684
# Feature: 3, Score: 0.29128
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.05199
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 台南市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x5_train, y5_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea5.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.66135
# Feature: 3, Score: 0.26186
# Feature: 4, Score: 0.07679
# Feature: 5, Score: 0.00000
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 高雄市

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x6_train, y6_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea6.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 0.48407
# Feature: 3, Score: 0.51593
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000
# <AxesSubplot:xlabel='feature'>

# %% [markdown]
# ### 歹灣

# %%
xgbr = XGBRegressor(learning_rate = 0.2, n_estimators = 40, max_depth = 1)
xgbr.fit(x7_train, y7_train)

# get importance
importance = xgbr.feature_importances_

# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i+1,v))

# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
plt.figure(figsize=(50, 50))
importances = pd.DataFrame({'feature':fea7.columns,'importance':np.round(xgbr.feature_importances_,3)}) 
importances = importances.sort_values('importance',ascending=False).set_index('feature')  
importances.plot.bar()
# Out:
# Feature: 1, Score: 0.00000
# Feature: 2, Score: 1.00000
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.00000
# Feature: 5, Score: 0.00000
# <AxesSubplot:xlabel='feature'>
